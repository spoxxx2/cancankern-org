# %%
import os
print('--- SPOXXX2 AUDITOR PROTOCOL ---')
print('Authenticating ICVCM Core Carbon Principles...')
os.system('kaggle datasets download -d spoxxx2/cancan-sovereign-beacon-mrv --unzip')
import json
with open('sovereign_beacon_af3.json', 'r') as f:
    af3_data = json.load(f)
print(f"Verified Asset ID: {af3_data['asset_id']}")
print(f"Patent Hash: {af3_data['patent_hash']}")
